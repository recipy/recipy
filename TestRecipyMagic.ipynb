# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !rm ~/.recipy/recipyDB.json

# %%
# %load_ext recipyCommon.magic

# %%
# !recipy search test.npy

# %%
# %recipyOn

# %%
import numpy

# %%
arr = numpy.arange(10)
arr = arr + 500

numpy.save('test.npy', arr)

# %%
# !recipy search test.npy

# %%
# %recipyOff

# %%
# !recipy search test.npy
